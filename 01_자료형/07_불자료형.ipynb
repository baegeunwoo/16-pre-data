# %%
# 불 자료형은 어떻게 사용할까
a = True
b= False
print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>

# %%
print(2>=1)
# Out:
# True

# %%
#if 0:
	#수행할 문장

print(bool("python"))
print(bool(""))

print(bool(10))
# Out:
# True
# False
# True

# %%
x=19
print(x >= 10 and x<20)
# Out:
# True
